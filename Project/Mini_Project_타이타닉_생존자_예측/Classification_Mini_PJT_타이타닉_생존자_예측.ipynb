# %% [markdown]
# ## Mini PJT.
#
# - `titanic` competition을 도전해봅시다!
#
# - 이번 프로젝트에서는 간단한 분류 문제를 풀어봅니다.
#
# - sklearn으로 머신러닝 모델을 구현해봅니다.
#
# - Machine Learning Workflow를 따라가봅니다.
#
#
# Source : https://www.kaggle.com/c/titanic

# %%
# colab 환경
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (1.22.4)
# Requirement already satisfied: matplotlib in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (3.5.2)
# Requirement already satisfied: numpy>=1.17 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: six>=1.5 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.23 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.1-cp310-cp310-macosx_12_0_arm64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 4.7 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from scikit-learn) (1.22.4)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 4.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3.2 in /Users/geun/miniforge3/envs/jupyter/lib/python3.10/site-packages (from scikit-learn) (1.8.1)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.1 threadpoolctl-3.1.0

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# titanic data 불러오기
base_path = './titanic_data/'

train = pd.read_csv(base_path + 'train.csv')
test = pd.read_csv(base_path + 'test.csv')
submission = pd.read_csv(base_path + 'gender_submission.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Data Preprocessing
#
# 1. 결측치 처리
#
#
# 2. feature selection (분석에 사용하지 않을 column 제거)

# %%
train.isnull().any(axis=1)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
# titanic data에서 missing value를 찾아봅니다.
train[train.isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [708 rows x 12 columns]

# %%
# Embarked column이 NaN인 row를 찾습니다.
train[train.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# 최빈값 확인
train.Embarked.value_counts()
# >> 최빈값 "S"
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.loc[(train.Pclass == 1) & (train.Sex == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %%
train.loc[(train.Pclass == 1) & (train.Sex == "female"), "Embarked"].value_counts()

# --> "S"로 채우자
# Out:
# S    48
# C    43
# Q     1
# Name: Embarked, dtype: int64

# %%
# 결측치를 S로 채우기
train.loc[train.Embarked.isnull(), "Embarked"] = "S"

# %%
# 잘 채워졌는지 확인
train.loc[(train.Pclass == 1) & (train.Sex == "female"), "Embarked"].value_counts()

# 48 -> 50 // 잘 채워졌다!
# Out:
# S    50
# C    43
# Q     1
# Name: Embarked, dtype: int64

# %%
# missing value를 handling 하자.
# column을 지울까? / 채울까?

# drop 할 column을 골라보자

train.Cabin.value_counts()

# Cabin 은 생존율에 영향이 없을 것 같다.
# PassengerId, Name, Ticket, Cabin --> Drop
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
# column drop 하기
train = train.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"])
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
# 'Age' column 채우기 ->> 평균 값으로 채우기
train = train.fillna(train.Age.mean())
train
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ### Feature Engineering
#
# 1. Categorical feature encoding
#
# 2. Normalization

# %%
# categorical feature --> One-hot Encoding, Ordinal Encoding

# 1. Ordinal Encoding -> Ordinal feature를 변환할 때 쓰임
#eg. 학력, 선호도, ...

# 2. One-hot Encoding -> Nominal feature를 변환할 때 쓰임
# eg. 성별, 부서, 출신학교, ...
# 컬럼을 만든 후 다른 데이터를 0 으로 만들어 주는게 'one'-hot Encodingd 이다.

train_OHE = pd.get_dummies(train, columns=["Sex", "Embarked"])
train_OHE
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.000000      1      0   7.2500           0         1
# 1           1       1  38.000000      1      0  71.2833           1         0
# 2           1       3  26.000000      0      0   7.9250           1         0
# 3           1       1  35.000000      1      0  53.1000           1         0
# 4           0       3  35.000000      0      0   8.0500           0         1
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 886         0       2  27.000000      0      0  13.0000           0         1
# 887         1       1  19.000000      0      0  30.0000           1         0
# 888         0       3  29.699118      1      2  23.4500           1         0
# 889         1       1  26.000000      0      0  30.0000           0         1
# 890         0       3  32.000000      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 11 columns]

# %%
# Normalization --> Min-Max scaling
X = train_OHE.drop(columns= "Survived") # input matrix
y = train_OHE.Survived                  # target vector

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# scaler.fit()
# scaler.transform()

X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[1.        , 0.27117366, 0.125     , ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.4722292 , 0.125     , ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.32143755, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.36792055, 0.125     , ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.32143755, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.39683338, 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
# X.Age = scaler.fit_transform(X.Age)
# X.Fare = scaler.fit_transform(X.Fare)
# X
temp = scaler.fit_transform(X.loc[:, ["Age", "Fare"]])
# temp.shape
X["Age"] = temp[:, 0]
X["Fare"] = temp[:, 1]

X
# Out:
#      Pclass       Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0         3  0.271174      1      0  0.014151           0         1
# 1         1  0.472229      1      0  0.139136           1         0
# 2         3  0.321438      0      0  0.015469           1         0
# 3         1  0.434531      1      0  0.103644           1         0
# 4         3  0.434531      0      0  0.015713           0         1
# ..      ...       ...    ...    ...       ...         ...       ...
# 886       2  0.334004      0      0  0.025374           0         1
# 887       1  0.233476      0      0  0.058556           1         0
# 888       3  0.367921      1      2  0.045771           1         0
# 889       1  0.321438      0      0  0.058556           0         1
# 890       3  0.396833      0      0  0.015127           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 10 columns]

# %% [markdown]
# ### Training

# %%
# sklearn에서 배웠던 분류 모델들을 불러와봅니다.
# 1. Linear Classifier
from sklearn.linear_model import SGDClassifier
# 2. Logistic Regression
from sklearn.linear_model import LogisticRegression
# 3. Decision Tree
from sklearn.tree import DecisionTreeClassifier
# 4. Random Forest
from sklearn.ensemble import RandomForestClassifier

# 평가지표
from sklearn.metrics import accuracy_score

# %%
clf = SGDClassifier()
clf2 = LogisticRegression()
clf3 = DecisionTreeClassifier()
clf4 = RandomForestClassifier()

clf.fit(X, y)
clf2.fit(X, y)
clf3.fit(X, y)
clf4.fit(X, y)

pred = clf.predict(X)
pred2 = clf2.predict(X)
pred3 = clf3.predict(X)
pred4 = clf3.predict(X)

# %%
print("1. Linear Classifier, Accuracy for training : %.4f" % accuracy_score(y, pred))
print("2. Logistic Regression, Accuracy for training : %.4f" % accuracy_score(y, pred2))
print("3. Decision Tree, Accuracy for training : %.4f" % accuracy_score(y, pred3))
print("4. Random Forest, Accuracy for training : %.4f" % accuracy_score(y, pred4))
# Out:
# 1. Linear Classifier, Accuracy for training : 0.7598
# 2. Logistic Regression, Accuracy for training : 0.8013
# 3. Decision Tree, Accuracy for training : 0.9820
# 4. Random Forest, Accuracy for training : 0.9820

# %% [markdown]
# ### Test (Predict)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
# test data에 같은 feature engineering을 적용해줍니다.
test = test.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"])
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Sex       418 non-null    object
#  2   Age       332 non-null    float64
#  3   SibSp     418 non-null    int64
#  4   Parch     418 non-null    int64
#  5   Fare      417 non-null    float64
#  6   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 23.0+ KB

# %%
# test = test.fillna(test.Age.mean())
# 이렇게 하면 문제가 생길 수 있다. 따라서 학습한 결과로 채워줘야한다.

# Imputation
test = test.fillna(train.Age.mean())
test = test.fillna(train.Fare.mean())

# Categorical feature encoding
test_OHE = pd.get_dummies(data=test, columns=["Sex", "Embarked"])

# Normalization
temp = scaler.transform(test_OHE.loc[:, ["Age", "Fare"]])
test_OHE.Age = temp[:, 0]
test_OHE.Fare = temp[:, 1]

# Check
test_OHE
# Out:
#      Pclass       Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0         3  0.428248      0      0  0.015282           0         1
# 1         3  0.585323      1      0  0.013663           1         0
# 2         2  0.773813      0      0  0.018909           0         1
# 3         3  0.334004      0      0  0.016908           0         1
# 4         3  0.271174      1      1  0.023984           1         0
# ..      ...       ...    ...    ...       ...         ...       ...
# 413       3  0.367921      0      0  0.015713           0         1
# 414       1  0.484795      0      0  0.212559           1         0
# 415       3  0.478512      0      0  0.014151           0         1
# 416       3  0.367921      0      0  0.015713           0         1
# 417       3  0.367921      1      1  0.043640           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# 1             0           0           1
# 2             0           1           0
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 413           0           0           1
# 414           1           0           0
# 415           0           0           1
# 416           0           0           1
# 417           1           0           0
#
# [418 rows x 10 columns]

# %%
# prediction
# test data 에 는 Y값 (survived) 가 없다.

result = clf.predict(test_OHE)
result2 = clf2.predict(test_OHE)
result3 = clf3.predict(test_OHE)
result4 = clf3.predict(test_OHE)

# %%
# 결과 파일인 submission.csv를 생성합니다.
submission["Survived"] = result4
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         1
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission.to_csv(base_path + "submission.csv", index = False)

# %% [markdown]
# [제출하러가기] https://www.kaggle.com/c/titanic
